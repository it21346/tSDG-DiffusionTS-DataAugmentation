# %%
from dataset import Dataset

# %%
data = Dataset('1h')
final_data_energy = data.preprocess()
# Out:
# /home/stelios-pc/Desktop/PhD/HALCOR/dataset.py:71: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x : np.nan if x == '-' else x) # convert - into nan so I can do fillna later
# /home/stelios-pc/Desktop/PhD/HALCOR/dataset.py:71: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x : np.nan if x == '-' else x) # convert - into nan so I can do fillna later
# /home/stelios-pc/Desktop/PhD/HALCOR/dataset.py:71: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x : np.nan if x == '-' else x) # convert - into nan so I can do fillna later
# /home/stelios-pc/Desktop/PhD/HALCOR/dataset.py:71: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x : np.nan if x == '-' else x) # convert - into nan so I can do fillna later
# ...

# %%
final_data_energy
# Out:
#               Timestamp   Real Energy          diff Product Group SKU code  \
# 0   2022-05-01 08:00:00  1.296980e+08  3.891417e+08         {DB3}    {1.0}
# 1   2022-05-01 12:00:00  5.188397e+08  3.891417e+08         {DB3}    {1.0}
# 2   2022-05-01 16:00:00  5.189115e+08  7.181542e+04         {DB3}    {1.0}
# 3   2022-05-01 20:00:00  5.189749e+08  6.334578e+04         {DB3}    {1.0}
# 4   2022-05-02 00:00:00  5.189935e+08  1.864765e+04         {DB3}    {1.0}
# ..                  ...           ...           ...           ...      ...
# 542 2022-07-30 16:00:00  5.465586e+08  7.050925e+04         {DB3}    {1.0}
# 543 2022-07-30 20:00:00  5.465841e+08  2.546358e+04         {DB3}    {1.0}
# 544 2022-07-31 00:00:00  5.465929e+08  8.796186e+03         {DB3}    {1.0}
# 545 2022-07-31 04:00:00  5.466415e+08  4.868635e+04         {DB3}    {1.0}
# 546 2022-07-31 08:00:00  4.100295e+08 -1.366120e+08         {DB3}    {1.0}
#
#                         Event Code_plc  Duration (sec)  \
# ...
